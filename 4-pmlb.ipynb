# %% [markdown]
# # Datasets and Benchmark
#
# Since we are going to play a bit with data and datasets - ultimately to show some examples of data analysis and machine learning -
# **in this notebook** we will present a quite new package in the Python ecosystem, i.e. `pmlb` that automatically provides datasets for data analysis and Machine Learning.
#
#
# ### Don't worry
#
# If you are an absolute beginner, or you simply don't know what Machine Learning is, **nothing to worry about**!
# We will talk about it in the next section! :)
#
# **In this notebook** we just focus on the `pmlb` package from a technical perspective.
#
# If you are completely new to concepts like **Supervised Learning**, **Classification**, or **Regression** come back to this notebook later after the "Introduction to Machine Learning" section for a quick recap and cross-check of these concepts !-)

# %% [markdown]
# ---

# %% [markdown]
# ## Introducting the Penn Machine Learning Benchmarks
#
# **Penn Machine Learning Benchmark** (`PMLB`) is a collection of code and data for a large, curated set of benchmark datasets for evaluating and comparing supervised machine learning algorithms.
#
# These data sets cover a broad range of applications, and include _binary/multi-class classification_ problems and _regression problems_, as well as combinations of categorical, ordinal, and continuous features.
#
# **There are no missing values in these data sets**.
#
# PMLB was developed in the [Computational Genetics Lab](http://epistasis.org/) at the [University of Pennsylvania](https://www.upenn.edu/) with funding from the [NIH](http://www.nih.gov/) under grant R01 AI117694.
#
# More information here: [github.com/EpistasisLab/penn-ml-benchmarks](https://github.com/EpistasisLab/penn-ml-benchmarks)

# %% [markdown]
# ## Data set format
#
# All data sets are stored in a common format:
#
# * First row is the column names
# * Each following row corresponds to one row of the data
# * The target column is named `target`
# * All columns are tab (`\t`) separated
# * All files are compressed with `gzip` to conserve space

# %% [markdown]
# ## Python wrapper
#
# For easy access to the benchmark data sets, we have provided a Python wrapper named `pmlb`. The wrapper can be installed on Python via `pip`:
#
# ```
# pip install pmlb
# ```
#
# and used in Python scripts as follows:

# %%
try: 
    import plmb
except ImportError:
    print('IMPORT ERROR: Please install the pmlb package: pip install pmlb')
# Out:
# IMPORT ERROR: Please install the pmlb package: pip install pmlb

# %%
# if you got an ImportError in the previous cell:

# !pip install pmlb
# Out:
# Collecting pmlb
#   Using cached https://files.pythonhosted.org/packages/0d/38/bb7bf1785add978af1e6c2bd27926405959c71ebaeefa6ff610bf53d8b25/pmlb-0.3.tar.gz
# Requirement already satisfied: pandas in /Users/valerio/anaconda3/envs/webvalley19/lib/python3.7/site-packages (from pmlb) (0.24.2)
# Requirement already satisfied: python-dateutil>=2.5.0 in /Users/valerio/anaconda3/envs/webvalley19/lib/python3.7/site-packages (from pandas->pmlb) (2.8.0)
# Requirement already satisfied: pytz>=2011k in /Users/valerio/anaconda3/envs/webvalley19/lib/python3.7/site-packages (from pandas->pmlb) (2019.1)
# Requirement already satisfied: numpy>=1.12.0 in /Users/valerio/anaconda3/envs/webvalley19/lib/python3.7/site-packages (from pandas->pmlb) (1.16.4)
# Requirement already satisfied: six>=1.5 in /Users/valerio/anaconda3/envs/webvalley19/lib/python3.7/site-packages (from python-dateutil>=2.5.0->pandas->pmlb) (1.12.0)
# Building wheels for collected packages: pmlb
#   Building wheel for pmlb (setup.py) ... done
#   Stored in directory: /Users/valerio/Library/Caches/pip/wheels/5a/c7/a4/be59e63a2cb56f6c58f068305b95c212e0aac1a930fd77d6b0
# Successfully built pmlb
# Installing collected packages: pmlb
# Successfully installed pmlb-0.3

# %% [markdown]
# #### Dataset List
#
# You can list **all** the available data sets in `pmlb` as it follows:

# %%
from pmlb import dataset_names

print('All Available Datasets: ')
print('========================')
for i, name in enumerate(dataset_names):
    print('{}) {}'.format(i+1, name))
# Out:
# All Available Datasets:
# ========================
# 1) GAMETES_Epistasis_2-Way_1000atts_0.4H_EDM-1_EDM-1_1
# 2) GAMETES_Epistasis_2-Way_20atts_0.1H_EDM-1_1
# 3) GAMETES_Epistasis_2-Way_20atts_0.4H_EDM-1_1
# 4) GAMETES_Epistasis_3-Way_20atts_0.2H_EDM-1_1
# 5) GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_50_EDM-2_001
# 6) GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_75_EDM-2_001
# 7) Hill_Valley_with_noise
# 8) Hill_Valley_without_noise
# 9) adult
# 10) agaricus-lepiota
# 11) allbp
# 12) allhyper
# 13) allhypo
# 14) allrep
# 15) analcatdata_aids
# 16) analcatdata_asbestos
# 17) analcatdata_authorship
# 18) analcatdata_bankruptcy
# 19) analcatdata_boxing1
# 20) analcatdata_boxing2
# 21) analcatdata_creditscore
# 22) analcatdata_cyyoung8092
# 23) analcatdata_cyyoung9302
# 24) analcatdata_dmft
# 25) analcatdata_fraud
# 26) analcatdata_germangss
# 27) analcatdata_happiness
# 28) analcatdata_japansolvent
# 29) analcatdata_lawsuit
# 30) ann-thyroid
# 31) appendicitis
# 32) australian
# 33) auto
# 34) backache
# 35) balance-scale
# 36) banana
# 37) biomed
# 38) breast
# 39) breast-cancer
# 40) breast-cancer-wisconsin
# 41) breast-w
# 42) buggyCrx
# 43) bupa
# 44) calendarDOW
# 45) car
# 46) car-evaluation
# 47) cars
# 48) cars1
# 49) chess
# 50) churn
# 51) clean1
# 52) clean2
# 53) cleve
# 54) cleveland
# 55) cleveland-nominal
# 56) cloud
# 57) cmc
# 58) coil2000
# 59) colic
# 60) collins
# 61) confidence
# 62) connect-4
# 63) contraceptive
# 64) corral
# 65) credit-a
# 66) credit-g
# 67) crx
# 68) dermatology
# 69) diabetes
# 70) dis
# 71) dna
# 72) ecoli
# 73) fars
# 74) flags
# 75) flare
# 76) german
# 77) glass
# 78) glass2
# 79) haberman
# 80) hayes-roth
# 81) heart-c
# 82) heart-h
# 83) heart-statlog
# 84) hepatitis
# 85) horse-colic
# 86) house-votes-84
# 87) hungarian
# 88) hypothyroid
# 89) ionosphere
# 90) iris
# 91) irish
# 92) kddcup
# 93) kr-vs-kp
# 94) krkopt
# 95) labor
# 96) led24
# 97) led7
# 98) letter
# 99) liver-disorder
# 100) lupus
# 101) lymphography
# 102) magic
# 103) mfeat-factors
# 104) mfeat-fourier
# 105) mfeat-karhunen
# 106) mfeat-morphological
# 107) mfeat-pixel
# 108) mfeat-zernike
# 109) mnist
# 110) mofn-3-7-10
# 111) molecular-biology_promoters
# 112) monk1
# 113) monk2
# 114) monk3
# 115) movement_libras
# 116) mushroom
# 117) mux6
# 118) new-thyroid
# 119) nursery
# 120) optdigits
# 121) page-blocks
# 122) parity5
# 123) parity5+5
# 124) pendigits
# 125) phoneme
# 126) pima
# 127) poker
# 128) postoperative-patient-data
# 129) prnn_crabs
# 130) prnn_fglass
# 131) prnn_synth
# 132) profb
# 133) promoters
# 134) ring
# 135) saheart
# 136) satimage
# 137) schizo
# 138) segmentation
# 139) shuttle
# 140) sleep
# 141) solar-flare_1
# 142) solar-flare_2
# 143) sonar
# 144) soybean
# 145) spambase
# 146) spect
# 147) spectf
# 148) splice
# 149) tae
# 150) texture
# 151) threeOf9
# 152) tic-tac-toe
# 153) titanic
# 154) tokyo1
# 155) twonorm
# 156) vehicle
# 157) vote
# 158) vowel
# 159) waveform-21
# 160) waveform-40
# 161) wdbc
# 162) wine-quality-red
# 163) wine-quality-white
# 164) wine-recognition
# 165) xd6
# 166) yeast
# 167) 1027_ESL
# 168) 1028_SWD
# 169) 1029_LEV
# 170) 1030_ERA
# 171) 1089_USCrime
# 172) 1096_FacultySalaries
# 173) 1191_BNG_pbc
# 174) 1193_BNG_lowbwt
# 175) 1196_BNG_pharynx
# 176) 1199_BNG_echoMonths
# 177) 1201_BNG_breastTumor
# 178) 1203_BNG_pwLinear
# 179) 1595_poker
# 180) 192_vineyard
# 181) 195_auto_price
# 182) 197_cpu_act
# 183) 201_pol
# 184) 207_autoPrice
# 185) 210_cloud
# 186) 215_2dplanes
# 187) 218_house_8L
# 188) 225_puma8NH
# 189) 227_cpu_small
# 190) 228_elusage
# 191) 229_pwLinear
# 192) 230_machine_cpu
# 193) 294_satellite_image
# 194) 344_mv
# 195) 4544_GeographicalOriginalofMusic
# 196) 485_analcatdata_vehicle
# 197) 503_wind
# 198) 505_tecator
# 199) 519_vinnie
# 200) 522_pm10
# 201) 523_analcatdata_neavote
# 202) 527_analcatdata_election2000
# 203) 529_pollen
# 204) 537_houses
# 205) 542_pollution
# 206) 547_no2
# 207) 556_analcatdata_apnea2
# 208) 557_analcatdata_apnea1
# 209) 560_bodyfat
# 210) 561_cpu
# 211) 562_cpu_small
# 212) 564_fried
# 213) 573_cpu_act
# 214) 574_house_16H
# 215) 579_fri_c0_250_5
# 216) 581_fri_c3_500_25
# 217) 582_fri_c1_500_25
# 218) 583_fri_c1_1000_50
# 219) 584_fri_c4_500_25
# 220) 586_fri_c3_1000_25
# 221) 588_fri_c4_1000_100
# 222) 589_fri_c2_1000_25
# 223) 590_fri_c0_1000_50
# 224) 591_fri_c1_100_10
# 225) 592_fri_c4_1000_25
# 226) 593_fri_c1_1000_10
# 227) 594_fri_c2_100_5
# 228) 595_fri_c0_1000_10
# 229) 596_fri_c2_250_5
# 230) 597_fri_c2_500_5
# 231) 598_fri_c0_1000_25
# 232) 599_fri_c2_1000_5
# 233) 601_fri_c1_250_5
# 234) 602_fri_c3_250_10
# 235) 603_fri_c0_250_50
# 236) 604_fri_c4_500_10
# 237) 605_fri_c2_250_25
# 238) 606_fri_c2_1000_10
# 239) 607_fri_c4_1000_50
# 240) 608_fri_c3_1000_10
# 241) 609_fri_c0_1000_5
# 242) 611_fri_c3_100_5
# 243) 612_fri_c1_1000_5
# 244) 613_fri_c3_250_5
# 245) 615_fri_c4_250_10
# 246) 616_fri_c4_500_50
# 247) 617_fri_c3_500_5
# 248) 618_fri_c3_1000_50
# 249) 620_fri_c1_1000_25
# 250) 621_fri_c0_100_10
# 251) 622_fri_c2_1000_50
# 252) 623_fri_c4_1000_10
# 253) 624_fri_c0_100_5
# 254) 626_fri_c2_500_50
# 255) 627_fri_c2_500_10
# 256) 628_fri_c3_1000_5
# 257) 631_fri_c1_500_5
# 258) 633_fri_c0_500_25
# 259) 634_fri_c2_100_10
# 260) 635_fri_c0_250_10
# 261) 637_fri_c1_500_50
# 262) 641_fri_c1_500_10
# 263) 643_fri_c2_500_25
# 264) 644_fri_c4_250_25
# 265) 645_fri_c3_500_50
# 266) 646_fri_c3_500_10
# 267) 647_fri_c1_250_10
# 268) 648_fri_c1_250_50
# 269) 649_fri_c0_500_5
# 270) 650_fri_c0_500_50
# 271) 651_fri_c0_100_25
# 272) 653_fri_c0_250_25
# 273) 654_fri_c0_500_10
# 274) 656_fri_c1_100_5
# 275) 657_fri_c2_250_10
# 276) 658_fri_c3_250_25
# 277) 659_sleuth_ex1714
# 278) 663_rabe_266
# 279) 665_sleuth_case2002
# 280) 666_rmftsa_ladata
# 281) 678_visualizing_environmental
# 282) 687_sleuth_ex1605
# 283) 690_visualizing_galaxy
# 284) 695_chatfield_4
# 285) 706_sleuth_case1202
# 286) 712_chscase_geyser1

# %% [markdown]
# Moreover, if you are particularly interested in getting the list of available datasets for **Classification** or **Regression**:

# %%
from pmlb import classification_dataset_names, regression_dataset_names

print('Classification Datasets: ')
print('=========================')
for i, name in enumerate(classification_dataset_names):
    print('{}) {}'.format(i+1, name))
# Out:
# Classification Datasets:
# =========================
# 1) GAMETES_Epistasis_2-Way_1000atts_0.4H_EDM-1_EDM-1_1
# 2) GAMETES_Epistasis_2-Way_20atts_0.1H_EDM-1_1
# 3) GAMETES_Epistasis_2-Way_20atts_0.4H_EDM-1_1
# 4) GAMETES_Epistasis_3-Way_20atts_0.2H_EDM-1_1
# 5) GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_50_EDM-2_001
# 6) GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_75_EDM-2_001
# 7) Hill_Valley_with_noise
# 8) Hill_Valley_without_noise
# 9) adult
# 10) agaricus-lepiota
# 11) allbp
# 12) allhyper
# 13) allhypo
# 14) allrep
# 15) analcatdata_aids
# 16) analcatdata_asbestos
# 17) analcatdata_authorship
# 18) analcatdata_bankruptcy
# 19) analcatdata_boxing1
# 20) analcatdata_boxing2
# 21) analcatdata_creditscore
# 22) analcatdata_cyyoung8092
# 23) analcatdata_cyyoung9302
# 24) analcatdata_dmft
# 25) analcatdata_fraud
# 26) analcatdata_germangss
# 27) analcatdata_happiness
# 28) analcatdata_japansolvent
# 29) analcatdata_lawsuit
# 30) ann-thyroid
# 31) appendicitis
# 32) australian
# 33) auto
# 34) backache
# 35) balance-scale
# 36) banana
# 37) biomed
# 38) breast
# 39) breast-cancer
# 40) breast-cancer-wisconsin
# 41) breast-w
# 42) buggyCrx
# 43) bupa
# 44) calendarDOW
# 45) car
# 46) car-evaluation
# 47) cars
# 48) cars1
# 49) chess
# 50) churn
# 51) clean1
# 52) clean2
# 53) cleve
# 54) cleveland
# 55) cleveland-nominal
# 56) cloud
# 57) cmc
# 58) coil2000
# 59) colic
# 60) collins
# 61) confidence
# 62) connect-4
# 63) contraceptive
# 64) corral
# 65) credit-a
# 66) credit-g
# 67) crx
# 68) dermatology
# 69) diabetes
# 70) dis
# 71) dna
# 72) ecoli
# 73) fars
# 74) flags
# 75) flare
# 76) german
# 77) glass
# 78) glass2
# 79) haberman
# 80) hayes-roth
# 81) heart-c
# 82) heart-h
# 83) heart-statlog
# 84) hepatitis
# 85) horse-colic
# 86) house-votes-84
# 87) hungarian
# 88) hypothyroid
# 89) ionosphere
# 90) iris
# 91) irish
# 92) kddcup
# 93) kr-vs-kp
# 94) krkopt
# 95) labor
# 96) led24
# 97) led7
# 98) letter
# 99) liver-disorder
# 100) lupus
# 101) lymphography
# 102) magic
# 103) mfeat-factors
# 104) mfeat-fourier
# 105) mfeat-karhunen
# 106) mfeat-morphological
# 107) mfeat-pixel
# 108) mfeat-zernike
# 109) mnist
# 110) mofn-3-7-10
# 111) molecular-biology_promoters
# 112) monk1
# 113) monk2
# 114) monk3
# 115) movement_libras
# 116) mushroom
# 117) mux6
# 118) new-thyroid
# 119) nursery
# 120) optdigits
# 121) page-blocks
# 122) parity5
# 123) parity5+5
# 124) pendigits
# 125) phoneme
# 126) pima
# 127) poker
# 128) postoperative-patient-data
# 129) prnn_crabs
# 130) prnn_fglass
# 131) prnn_synth
# 132) profb
# 133) promoters
# 134) ring
# 135) saheart
# 136) satimage
# 137) schizo
# 138) segmentation
# 139) shuttle
# 140) sleep
# 141) solar-flare_1
# 142) solar-flare_2
# 143) sonar
# 144) soybean
# 145) spambase
# 146) spect
# 147) spectf
# 148) splice
# 149) tae
# 150) texture
# 151) threeOf9
# 152) tic-tac-toe
# 153) titanic
# 154) tokyo1
# 155) twonorm
# 156) vehicle
# 157) vote
# 158) vowel
# 159) waveform-21
# 160) waveform-40
# 161) wdbc
# 162) wine-quality-red
# 163) wine-quality-white
# 164) wine-recognition
# 165) xd6
# 166) yeast

# %%
print('Regression Datasets: ')
print('=========================')
for i, name in enumerate(regression_dataset_names):
    print('{}) {}'.format(i+1, name))
# Out:
# Regression Datasets:
# =========================
# 1) 1027_ESL
# 2) 1028_SWD
# 3) 1029_LEV
# 4) 1030_ERA
# 5) 1089_USCrime
# 6) 1096_FacultySalaries
# 7) 1191_BNG_pbc
# 8) 1193_BNG_lowbwt
# 9) 1196_BNG_pharynx
# 10) 1199_BNG_echoMonths
# 11) 1201_BNG_breastTumor
# 12) 1203_BNG_pwLinear
# 13) 1595_poker
# 14) 192_vineyard
# 15) 195_auto_price
# 16) 197_cpu_act
# 17) 201_pol
# 18) 207_autoPrice
# 19) 210_cloud
# 20) 215_2dplanes
# 21) 218_house_8L
# 22) 225_puma8NH
# 23) 227_cpu_small
# 24) 228_elusage
# 25) 229_pwLinear
# 26) 230_machine_cpu
# 27) 294_satellite_image
# 28) 344_mv
# 29) 4544_GeographicalOriginalofMusic
# 30) 485_analcatdata_vehicle
# 31) 503_wind
# 32) 505_tecator
# 33) 519_vinnie
# 34) 522_pm10
# 35) 523_analcatdata_neavote
# 36) 527_analcatdata_election2000
# 37) 529_pollen
# 38) 537_houses
# 39) 542_pollution
# 40) 547_no2
# 41) 556_analcatdata_apnea2
# 42) 557_analcatdata_apnea1
# 43) 560_bodyfat
# 44) 561_cpu
# 45) 562_cpu_small
# 46) 564_fried
# 47) 573_cpu_act
# 48) 574_house_16H
# 49) 579_fri_c0_250_5
# 50) 581_fri_c3_500_25
# 51) 582_fri_c1_500_25
# 52) 583_fri_c1_1000_50
# 53) 584_fri_c4_500_25
# 54) 586_fri_c3_1000_25
# 55) 588_fri_c4_1000_100
# 56) 589_fri_c2_1000_25
# 57) 590_fri_c0_1000_50
# 58) 591_fri_c1_100_10
# 59) 592_fri_c4_1000_25
# 60) 593_fri_c1_1000_10
# 61) 594_fri_c2_100_5
# 62) 595_fri_c0_1000_10
# 63) 596_fri_c2_250_5
# 64) 597_fri_c2_500_5
# 65) 598_fri_c0_1000_25
# 66) 599_fri_c2_1000_5
# 67) 601_fri_c1_250_5
# 68) 602_fri_c3_250_10
# 69) 603_fri_c0_250_50
# 70) 604_fri_c4_500_10
# 71) 605_fri_c2_250_25
# 72) 606_fri_c2_1000_10
# 73) 607_fri_c4_1000_50
# 74) 608_fri_c3_1000_10
# 75) 609_fri_c0_1000_5
# 76) 611_fri_c3_100_5
# 77) 612_fri_c1_1000_5
# 78) 613_fri_c3_250_5
# 79) 615_fri_c4_250_10
# 80) 616_fri_c4_500_50
# 81) 617_fri_c3_500_5
# 82) 618_fri_c3_1000_50
# 83) 620_fri_c1_1000_25
# 84) 621_fri_c0_100_10
# 85) 622_fri_c2_1000_50
# 86) 623_fri_c4_1000_10
# 87) 624_fri_c0_100_5
# 88) 626_fri_c2_500_50
# 89) 627_fri_c2_500_10
# 90) 628_fri_c3_1000_5
# 91) 631_fri_c1_500_5
# 92) 633_fri_c0_500_25
# 93) 634_fri_c2_100_10
# 94) 635_fri_c0_250_10
# 95) 637_fri_c1_500_50
# 96) 641_fri_c1_500_10
# 97) 643_fri_c2_500_25
# 98) 644_fri_c4_250_25
# 99) 645_fri_c3_500_50
# 100) 646_fri_c3_500_10
# 101) 647_fri_c1_250_10
# 102) 648_fri_c1_250_50
# 103) 649_fri_c0_500_5
# 104) 650_fri_c0_500_50
# 105) 651_fri_c0_100_25
# 106) 653_fri_c0_250_25
# 107) 654_fri_c0_500_10
# 108) 656_fri_c1_100_5
# 109) 657_fri_c2_250_10
# 110) 658_fri_c3_250_25
# 111) 659_sleuth_ex1714
# 112) 663_rabe_266
# 113) 665_sleuth_case2002
# 114) 666_rmftsa_ladata
# 115) 678_visualizing_environmental
# 116) 687_sleuth_ex1605
# 117) 690_visualizing_galaxy
# 118) 695_chatfield_4
# 119) 706_sleuth_case1202
# 120) 712_chscase_geyser1

# %% [markdown]
# ## Fetching a Dataset
#
# To fetch data from a dataset in `pmlb` it is just necessary the **name** of the dataset.
#
# By default, a `pandas.DataFrame` will be returned as output.

# %%
# Returns a pandas DataFrame
from pmlb import fetch_data

adult_data = fetch_data('adult')
print(adult_data.describe())
# Out:
#                 age     workclass        fnlwgt     education  education-num  \
# count  48842.000000  48842.000000  4.884200e+04  48842.000000   48842.000000
# mean      38.643585      3.870439  1.896641e+05     10.288420      10.078089
# std       13.710510      1.464234  1.056040e+05      3.874492       2.570973
# min       17.000000      0.000000  1.228500e+04      0.000000       1.000000
# 25%       28.000000      4.000000  1.175505e+05      9.000000       9.000000
# 50%       37.000000      4.000000  1.781445e+05     11.000000      10.000000
# 75%       48.000000      4.000000  2.376420e+05     12.000000      12.000000
# max       90.000000      8.000000  1.490400e+06     15.000000      16.000000
#
#        marital-status    occupation  relationship          race           sex  \
# count    48842.000000  48842.000000  48842.000000  48842.000000  48842.000000
# mean         2.618750      6.577700      1.443287      3.668052      0.668482
# std          1.507703      4.230509      1.602151      0.845986      0.470764
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# 25%          2.000000      3.000000      0.000000      4.000000      0.000000
# 50%          2.000000      7.000000      1.000000      4.000000      1.000000
# 75%          4.000000     10.000000      3.000000      4.000000      1.000000
# max          6.000000     14.000000      5.000000      4.000000      1.000000
#
#        capital-gain  capital-loss  hours-per-week  native-country  \
# count  48842.000000  48842.000000    48842.000000    48842.000000
# mean    1079.067626     87.502314       40.422382       36.749355
# std     7452.019058    403.004552       12.391444        7.775343
# min        0.000000      0.000000        1.000000        0.000000
# 25%        0.000000      0.000000       40.000000       39.000000
# 50%        0.000000      0.000000       40.000000       39.000000
# 75%        0.000000      0.000000       45.000000       39.000000
# max    99999.000000   4356.000000       99.000000       41.000000
#
#              target
# count  48842.000000
# mean       0.760718
# std        0.426649
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %% [markdown]
# In the next notebooks, we will be using this **package** to easily download and use datasets for further analysis and manipulations

# %% [markdown]
# ---

# %% [markdown]
# ### Feel free to SKIP
#
# Please feel free to **skip** the rest of this notebook and come back to it later once we will introduce **NumPy**, and
# **Scikit-learn** for Machine Learning.

# %% [markdown]
# The `fetch_data` function has two additional parameters:
#
# * `return_X_y` (True/False): Whether to return the data in scikit-learn format, with the features and labels stored in separate NumPy arrays.
#
# * `local_cache_dir` (string): The directory on your local machine to store the data files so you don't have to fetch them over the web again. By default, the wrapper does not use a local cache directory.
#
# For example:

# %%
from pmlb import fetch_data

# Returns NumPy arrays
adult_X, adult_y = fetch_data('adult', return_X_y=True, local_cache_dir='./data')
print(adult_X)
print(adult_y)
# Out:
# [[3.90000e+01 7.00000e+00 7.75160e+04 ... 0.00000e+00 4.00000e+01
#   3.90000e+01]
#  [5.00000e+01 6.00000e+00 8.33110e+04 ... 0.00000e+00 1.30000e+01
#   3.90000e+01]
#  [3.80000e+01 4.00000e+00 2.15646e+05 ... 0.00000e+00 4.00000e+01
#   3.90000e+01]
#  ...
#  [3.80000e+01 4.00000e+00 3.74983e+05 ... 0.00000e+00 5.00000e+01
#   3.90000e+01]
#  [4.40000e+01 4.00000e+00 8.38910e+04 ... 0.00000e+00 4.00000e+01
#   3.90000e+01]
#  [3.50000e+01 5.00000e+00 1.82148e+05 ... 0.00000e+00 6.00000e+01
#   3.90000e+01]]
# [1 1 1 ... 1 1 0]

# %% [markdown]
# ## Example usage: Compare two classification algorithms with PMLB
#
# PMLB is designed to make it easy to benchmark machine learning algorithms against each other.
#
# Below is a Python code snippet showing the most basic way to use PMLB to compare two algorithms.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import seaborn as sb

from pmlb import fetch_data, classification_dataset_names

# %%
logit_test_scores = []
gnb_test_scores = []

for i, classification_dataset in enumerate(classification_dataset_names):
    if i > 20:
        break
        
    X, y = fetch_data(classification_dataset, return_X_y=True)
    train_X, test_X, train_y, test_y = train_test_split(X, y)

    logit = LogisticRegression(solver='liblinear', multi_class='auto', )
    gnb = GaussianNB()

    logit.fit(train_X, train_y)
    gnb.fit(train_X, train_y)

    logit_test_scores.append(logit.score(test_X, test_y))
    gnb_test_scores.append(gnb.score(test_X, test_y))
    print('{} {} DONE'.format(i+1, classification_dataset))

sb.boxplot(data=[logit_test_scores, gnb_test_scores], notch=True)
plt.xticks([0, 1], ['LogisticRegression', 'GaussianNB'])
plt.ylabel('Test Accuracy')
# Out:
# 1 GAMETES_Epistasis_2-Way_1000atts_0.4H_EDM-1_EDM-1_1 DONE
# 2 GAMETES_Epistasis_2-Way_20atts_0.1H_EDM-1_1 DONE
# 3 GAMETES_Epistasis_2-Way_20atts_0.4H_EDM-1_1 DONE
# 4 GAMETES_Epistasis_3-Way_20atts_0.2H_EDM-1_1 DONE
# 5 GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_50_EDM-2_001 DONE
# 6 GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_75_EDM-2_001 DONE
# /Users/valerio/anaconda3/envs/webvalley19/lib/python3.7/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 7 Hill_Valley_with_noise DONE
# 8 Hill_Valley_without_noise DONE
# 9 adult DONE
# 10 agaricus-lepiota DONE
# 11 allbp DONE
# 12 allhyper DONE
# 13 allhypo DONE
# 14 allrep DONE
# 15 analcatdata_aids DONE
# 16 analcatdata_asbestos DONE
# 17 analcatdata_authorship DONE
# 18 analcatdata_bankruptcy DONE
# 19 analcatdata_boxing1 DONE
# 20 analcatdata_boxing2 DONE
# 21 analcatdata_creditscore DONE
# Text(0, 0.5, 'Test Accuracy')
